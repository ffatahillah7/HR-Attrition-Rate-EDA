# %% [markdown]
# # EDA HR ANALYTICS ATTRITION RATE

# %% [markdown]
# ## Import Library Needed

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %% [markdown]
# ## Read Dataset , Upload as DataFrame pandas

# %%
df = pd.read_excel('C:\\Users\\ffatahillah\\Downloads\\HR_Data.xlsx')
df
# Out:
#      Attrition    Business Travel CF_age band CF_attrition label Department  \
# 0          Yes      Travel_Rarely     35 - 44       Ex-Employees      Sales
# 1           No  Travel_Frequently     45 - 54  Current Employees        R&D
# 2          Yes      Travel_Rarely     35 - 44       Ex-Employees        R&D
# 3           No  Travel_Frequently     25 - 34  Current Employees        R&D
# 4           No      Travel_Rarely     25 - 34  Current Employees        R&D
# ...        ...                ...         ...                ...        ...
# 1465       Yes         Non-Travel     25 - 34       Ex-Employees        R&D
# 1466       Yes  Travel_Frequently     25 - 34       Ex-Employees        R&D
# 1467       Yes  Travel_Frequently     35 - 44       Ex-Employees      Sales
# 1468       Yes      Travel_Rarely    Under 25       Ex-Employees        R&D
# 1469       Yes      Travel_Rarely    Under 25       Ex-Employees      Sales
#
# ...

# %% [markdown]
# ## Show info about Dataset

# %%
df.head(10)
# Out:
#   Attrition    Business Travel CF_age band CF_attrition label Department  \
# 0       Yes      Travel_Rarely     35 - 44       Ex-Employees      Sales
# 1        No  Travel_Frequently     45 - 54  Current Employees        R&D
# 2       Yes      Travel_Rarely     35 - 44       Ex-Employees        R&D
# 3        No  Travel_Frequently     25 - 34  Current Employees        R&D
# 4        No      Travel_Rarely     25 - 34  Current Employees        R&D
# 5        No  Travel_Frequently     25 - 34  Current Employees        R&D
# 6        No      Travel_Rarely     Over 55  Current Employees        R&D
# 7        No      Travel_Rarely     25 - 34  Current Employees        R&D
# 8        No  Travel_Frequently     35 - 44  Current Employees        R&D
# 9        No      Travel_Rarely     35 - 44  Current Employees        R&D
#
#   Education Field    emp no  Employee Number  Gender  \
# 0   Life Sciences   STAFF-1                1  Female
# 1   Life Sciences   STAFF-2                2    Male
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 39 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Attrition                   1470 non-null   object
#  1   Business Travel             1470 non-null   object
#  2   CF_age band                 1470 non-null   object
#  3   CF_attrition label          1470 non-null   object
#  4   Department                  1470 non-null   object
#  5   Education Field             1470 non-null   object
#  6   emp no                      1470 non-null   object
#  7   Employee Number             1470 non-null   int64
#  8   Gender                      1470 non-null   object
#  9   Job Role                    1470 non-null   object
#  10  Marital Status              1470 non-null   object
#  11  Over Time                   1470 non-null   object
#  12  Over18                      1470 non-null   object
# ...

# %% [markdown]
# ### Describe All Measurement as first conclution ( Mean, Std, Min, Max, Count)

# %%
df.describe()
# Out:
#        Employee Number  Training Times Last Year          Age  \
# count      1470.000000               1470.000000  1470.000000
# mean       1024.865306                  2.799320    36.923810
# std         602.024335                  1.289271     9.135373
# min           1.000000                  0.000000    18.000000
# 25%         491.250000                  2.000000    30.000000
# 50%        1020.500000                  3.000000    36.000000
# 75%        1555.750000                  3.000000    43.000000
# max        2068.000000                  6.000000    60.000000
#
#        CF_current Employee   Daily Rate  Distance From Home  Employee Count  \
# count          1470.000000  1470.000000         1470.000000          1470.0
# mean              0.838776   802.485714            9.192517             1.0
# std               0.367863   403.509100            8.106864             0.0
# min               0.000000   102.000000            1.000000             1.0
# ...

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ### Check Null Value

# %%
df.isnull().sum()
# Out:
# Attrition                     0
# Business Travel               0
# CF_age band                   0
# CF_attrition label            0
# Department                    0
# Education Field               0
# emp no                        0
# Employee Number               0
# Gender                        0
# Job Role                      0
# Marital Status                0
# Over Time                     0
# Over18                        0
# Training Times Last Year      0
# Age                           0
# CF_current Employee           0
# Daily Rate                    0
# Distance From Home            0
# Education                     0
# Employee Count                0
# Environment Satisfaction      0
# Hourly Rate                   0
# Job Involvement               0
# Job Level                     0
# Job Satisfaction              0
# Monthly Income                0
# Monthly Rate                  0
# Num Companies Worked          0
# Percent Salary Hike           0
# ...

# %% [markdown]
# ### Find Unique Value from each column if needed (Object)

# %%
df['Department'].unique()
# Out:
# array(['Sales', 'R&D', 'HR'], dtype=object)

# %%
df['Education Field'].unique()
# Out:
# array(['Life Sciences', 'Other', 'Medical', 'Marketing',
#        'Technical Degree', 'Human Resources'], dtype=object)

# %%
df['Education'].unique()
# Out:
# array(['Associates Degree', 'High School', "Master's Degree",
#        "Bachelor's Degree", 'Doctoral Degree'], dtype=object)

# %%
df['Job Role'].unique()
# Out:
# array(['Sales Executive', 'Research Scientist', 'Laboratory Technician',
#        'Manufacturing Director', 'Healthcare Representative', 'Manager',
#        'Sales Representative', 'Research Director', 'Human Resources'],
#       dtype=object)

# %% [markdown]
# ### Replace Unnecessary sign, space, etc

# %%
df.columns = df.columns.str.strip()

# %%
df.columns = df.columns.str.replace(' ','')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 39 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Attrition                 1470 non-null   object
#  1   BusinessTravel            1470 non-null   object
#  2   CF_ageband                1470 non-null   object
#  3   CF_attritionlabel         1470 non-null   object
#  4   Department                1470 non-null   object
#  5   EducationField            1470 non-null   object
#  6   empno                     1470 non-null   object
#  7   EmployeeNumber            1470 non-null   int64
#  8   Gender                    1470 non-null   object
#  9   JobRole                   1470 non-null   object
#  10  MaritalStatus             1470 non-null   object
#  11  OverTime                  1470 non-null   object
#  12  Over18                    1470 non-null   object
# ...

# %% [markdown]
# ### Transform Column that have unique values to Category Data Type

# %%
df['Department'] = df['Department'].astype('category')
df['EducationField'] = df['EducationField'].astype('category')
df['JobRole'] = df['JobRole'].astype('category')
df['Education'] = df['Education'].astype('category')
df['Gender'] = df['Gender'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 39 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Attrition                 1470 non-null   object
#  1   BusinessTravel            1470 non-null   object
#  2   CF_ageband                1470 non-null   object
#  3   CF_attritionlabel         1470 non-null   object
#  4   Department                1470 non-null   category
#  5   EducationField            1470 non-null   category
#  6   empno                     1470 non-null   object
#  7   EmployeeNumber            1470 non-null   int64
#  8   Gender                    1470 non-null   category
#  9   JobRole                   1470 non-null   category
#  10  MaritalStatus             1470 non-null   object
#  11  OverTime                  1470 non-null   object
#  12  Over18                    1470 non-null   object
# ...

# %% [markdown]
# ### Saving Data Frame to Excel File

# %%
#set file NAme
file_name = 'C:\\Users\\ffatahillah\\Downloads\\HR_Data_Fix.xlsx'

#Export to excel file
df.to_excel(file_name)
print("Data Frame is written to excel file successfully")
# Out:
# Data Frame is written to excel file successfully

# %% [markdown]
# # DATA VISUALIZATION

# %%
import matplotlib.pyplot as plt
# Count by Departmen Level 
sns.countplot(x="Department", data=df)
plt.xticks(rotation=0)
plt.title("Count all Employee by Department Level")
plt.show()
# Out:
# C:\Users\ffatahillah\AppData\Local\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
# Count by Education Field
sns.countplot(x="EducationField", data=df)
plt.xticks(rotation = 0)
plt.title('Count All Employee by Education Field')
plt.show()
# Out:
# C:\Users\ffatahillah\AppData\Local\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
f, ax = plt.subplots(1, 1, figsize=(12, 8))
ax = sns.barplot(x='Attrition', y='EmployeeNumber', hue='EducationField', data=df, palette='cool')

# %%
f, ax = plt.subplots(1, 1, figsize=(12,8))
ax = sns.barplot(x='Attrition', y='EmployeeNumber', hue='Education', data=df, palette='cool')

# %%
##Converting category labels into numerical using LabelEncoder for create correlation matrix.
## Attrition yes/no to 1/0

from sklearn.preprocessing import LabelEncoder

label = LabelEncoder()
df.Attrition = label.fit_transform(df.Attrition)
df.Department = label.fit_transform(df.Department)
df.EducationField = label.fit_transform(df.EducationField)
df.JobRole = label.fit_transform(df.JobRole)
df.Gender = label.fit_transform(df.Gender)
df.Education = label.fit_transform(df.Education)
df.BusinessTravel = label.fit_transform(df.BusinessTravel)
df.CF_ageband = label.fit_transform(df.CF_ageband)
df.CF_attritionlabel = label.fit_transform(df.CF_attritionlabel)
df.empno = label.fit_transform(df.empno)
df.MaritalStatus = label.fit_transform(df.MaritalStatus)
df.OverTime = label.fit_transform(df.OverTime)
df.Over18 = label.fit_transform(df.Over18)
df.dtypes
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 39 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Attrition                 1470 non-null   int64
#  1   BusinessTravel            1470 non-null   int64
#  2   CF_ageband                1470 non-null   int64
#  3   CF_attritionlabel         1470 non-null   int64
#  4   Department                1470 non-null   int64
#  5   EducationField            1470 non-null   int64
#  6   empno                     1470 non-null   int64
#  7   EmployeeNumber            1470 non-null   int64
#  8   Gender                    1470 non-null   int64
#  9   JobRole                   1470 non-null   int64
#  10  MaritalStatus             1470 non-null   int32
#  11  OverTime                  1470 non-null   int32
#  12  Over18                    1470 non-null   int32
#  13  TrainingTimesLastYear     1470 non-null   int64
# ...

# %%
# Create HeatMap or Correlation Visual

f, ax = plt.subplots(1, 1, figsize=(12,8))
ax = sns.heatmap(df.corr(), annot=True, cmap='cool')
# Out:
# C:\Users\ffatahillah\AppData\Local\anaconda3\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)
